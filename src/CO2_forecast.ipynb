# %% [markdown]
# # Import

# %%
import numpy as np
import pandas as pd
import sklearn

# %%
co2 = pd.read_csv("/notebooks/MLProject/data/CO2.EQ/API_EN.ATM.GHGT.KT.CE_DS2_en_csv_v2_5872248.csv")
co2.head(5)
# Out:
#          Data Source World Development Indicators  \
# 0                NaN                          NaN
# 1  Last Updated Date                   19/09/2023
# 2                NaN                          NaN
# 3       Country Name                 Country Code
# 4              Aruba                          ABW
#
#                                           Unnamed: 2         Unnamed: 3  \
# 0                                                NaN                NaN
# 1                                                NaN                NaN
# 2                                                NaN                NaN
# 3                                     Indicator Name     Indicator Code
# 4  Total greenhouse gas emissions (kt of CO2 equi...  EN.ATM.GHGT.KT.CE
#
#    Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# ...
